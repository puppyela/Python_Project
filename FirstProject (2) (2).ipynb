# %%
import pandas as pd

# %%
pd.read_csv("historical_RAPTOR_by_player.csv")
# Out:
#           player_name  player_id  season  poss    mp  raptor_offense  \
# 0      Alaa Abdelnaby  abdelal01    1991   640   303       -3.938450
# 1      Alaa Abdelnaby  abdelal01    1992  1998   959       -2.553849
# 2      Alaa Abdelnaby  abdelal01    1993  2754  1379       -2.373736
# 3      Alaa Abdelnaby  abdelal01    1994   320   159       -6.140056
# 4      Alaa Abdelnaby  abdelal01    1995   984   506       -3.846543
# ...               ...        ...     ...   ...   ...             ...
# 19154     Ivica Zubac  zubaciv01    2018   871   410       -2.903709
# 19155     Ivica Zubac  zubaciv01    2019  2345  1079       -2.362444
# 19156     Ivica Zubac  zubaciv01    2020  3447  1646        1.099849
# 19157     Ivica Zubac  zubaciv01    2021  3908  1910       -0.909039
# 19158     Ivica Zubac  zubaciv01    2022  3786  1852       -0.693765
#
#        raptor_defense  raptor_total  war_total  war_reg_season  war_playoffs  \
# ...

# %%
df=pd.read_csv("historical_RAPTOR_by_player.csv")

# %%
# Section 2 Pandas Basics
#1st Question 
df.head(10)
# Out:
#            player_name  player_id  season  poss    mp  raptor_offense  \
# 0       Alaa Abdelnaby  abdelal01    1991   640   303       -3.938450
# 1       Alaa Abdelnaby  abdelal01    1992  1998   959       -2.553849
# 2       Alaa Abdelnaby  abdelal01    1993  2754  1379       -2.373736
# 3       Alaa Abdelnaby  abdelal01    1994   320   159       -6.140056
# 4       Alaa Abdelnaby  abdelal01    1995   984   506       -3.846543
# 5  Kareem Abdul-Jabbar  abdulka01    1977  7674  3483        4.544044
# 6  Kareem Abdul-Jabbar  abdulka01    1978  5343  2399        3.447574
# 7  Kareem Abdul-Jabbar  abdulka01    1979  7826  3524        2.950435
# 8  Kareem Abdul-Jabbar  abdulka01    1980  8226  3761        3.121840
# 9  Kareem Abdul-Jabbar  abdulka01    1981  6716  3110        2.374990
#
#    raptor_defense  raptor_total  war_total  war_reg_season  war_playoffs  \
# 0       -0.510076     -4.448526  -0.265191       -0.226163     -0.039028
# ...

# %%
#2 question 
df.nunique()
# Out:
# player_name          3571
# player_id            3591
# season                 46
# poss                 6448
# mp                   3603
# raptor_offense      19159
# raptor_defense      19158
# raptor_total        19159
# war_total           19156
# war_reg_season      19145
# war_playoffs         8545
# predator_offense    19159
# predator_defense    19159
# predator_total      19159
# pace_impact         19148
# dtype: int64

# %%
#3rd Question.
# To look for the player name Lebron James
a=df[df.player_name =="LeBron James"]
# to find the Unique seaons  
a.season.nunique()
# Out:
# 19

# %%
#4th Question 
#Show the rows where a player has total possessions are greater than 1000.
df[df.poss>1000]
# Out:
#                player_name  player_id  season  poss    mp  raptor_offense  \
# 1           Alaa Abdelnaby  abdelal01    1992  1998   959       -2.553849
# 2           Alaa Abdelnaby  abdelal01    1993  2754  1379       -2.373736
# 5      Kareem Abdul-Jabbar  abdulka01    1977  7674  3483        4.544044
# 6      Kareem Abdul-Jabbar  abdulka01    1978  5343  2399        3.447574
# 7      Kareem Abdul-Jabbar  abdulka01    1979  7826  3524        2.950435
# ...                    ...        ...     ...   ...   ...             ...
# 19153          Ivica Zubac  zubaciv01    2017  1305   609       -3.358178
# 19155          Ivica Zubac  zubaciv01    2019  2345  1079       -2.362444
# 19156          Ivica Zubac  zubaciv01    2020  3447  1646        1.099849
# 19157          Ivica Zubac  zubaciv01    2021  3908  1910       -0.909039
# 19158          Ivica Zubac  zubaciv01    2022  3786  1852       -0.693765
#
#        raptor_defense  raptor_total  war_total  war_reg_season  war_playoffs  \
# ...

# %%
#Filtering and aggregation
#1st Question 
#Filter players who had a `total_raptor` &gt; 5 in any season.
df[df.raptor_total>5]
# Out:
#                player_name  player_id  season  poss    mp  raptor_offense  \
# 5      Kareem Abdul-Jabbar  abdulka01    1977  7674  3483        4.544044
# 6      Kareem Abdul-Jabbar  abdulka01    1978  5343  2399        3.447574
# 7      Kareem Abdul-Jabbar  abdulka01    1979  7826  3524        2.950435
# 8      Kareem Abdul-Jabbar  abdulka01    1980  8226  3761        3.121840
# 88            Jaylen Adams  adamsja01    2020    43    21        6.207690
# ...                    ...        ...     ...   ...   ...             ...
# 18824        David Wingate  wingada01    2001    17     9       11.489484
# 18950     Haywoode Workman  workmha01    1990    32    16        5.442697
# 19013        Dorell Wright  wrighdo01    2016    39    19       13.549228
# 19074       Korleone Young  youngko01    1999    27    15       11.882869
# 19134         Tyler Zeller  zellety01    2020     9     4       10.352775
#
#        raptor_defense  raptor_total  war_total  war_reg_season  war_playoffs  \
# ...

# %%
#2nd Question 
#What are the top 5 players by `total_war` for the 2020 season?
p=df[df.season == 2020]
p.sort_values(by='war_total', ascending =False).head(5)
# Out:
#                  player_name  player_id  season  poss    mp  raptor_offense  \
# 7042            James Harden  hardeja01    2020  6253  2931        8.488456
# 8528            LeBron James  jamesle01    2020  6458  3078        6.494468
# 4103           Anthony Davis  davisan02    2020  6113  2900        3.083301
# 10206          Kawhi Leonard  leonaka01    2020  4919  2359        6.385148
# 526    Giannis Antetokounmpo  antetgi01    2020  4894  2194        5.338599
#
#        raptor_defense  raptor_total  war_total  war_reg_season  war_playoffs  \
# 7042         1.978387     10.466843  19.842384       16.705593      3.136792
# 8528         1.332666      7.827133  16.822484       11.591113      5.231372
# 4103         4.347303      7.430605  15.493170        9.303934      6.189236
# 10206        3.253238      9.638386  14.910511       11.730348      3.180163
# 526          3.439668      8.778267  13.149613       12.031285      1.118328
#
# ...

# %%
#3rd Question There is no colum name team in this data 
#Find the average `offensive_raptor` per team in the 2019 season.
df[df.season ==2019]
df['raptor_offense'].mean()
# Out:
# -1.2825723188410094

# %%
#4th Question 
#Group the data by season and calculate the total `war` per season.
df.groupby('season').sum()
# Out:
#                                               player_name  \
# season
# 1977    Kareem Abdul-JabbarZaid Abdul-AzizTom Aberneth...
# 1978    Kareem Abdul-JabbarZaid Abdul-AzizTom Aberneth...
# 1979    Kareem Abdul-JabbarTom AbernethyAlvan AdamsLuc...
# 1980    Kareem Abdul-JabbarTom AbernethyAlvan AdamsTin...
# 1981    Kareem Abdul-JabbarTom AbernethyAlvan AdamsDar...
# 1982    Kareem Abdul-JabbarAlvan AdamsMark AguirreDann...
# 1983    Kareem Abdul-JabbarAlvan AdamsMark AguirreDann...
# 1984    Kareem Abdul-JabbarAlvan AdamsMark AguirreDann...
# 1985    Kareem Abdul-JabbarAlvan AdamsMark AguirreDann...
# 1986    Kareem Abdul-JabbarAlvan AdamsMichael AdamsMar...
# 1987    Kareem Abdul-JabbarAlvan AdamsMichael AdamsRaf...
# 1988    Kareem Abdul-JabbarMark AcresAlvan AdamsMichae...
# 1989    Kareem Abdul-JabbarMark AcresMichael AdamsMark...
# 1990    Mark AcresMichael AdamsMark AguirreDanny Ainge...
# 1991    Alaa AbdelnabyMahmoud Abdul-RaufMark AcresMich...
# ...

# %%
#Section 4 Data Cleaning
#question no 1
#Check if there are any missing values in the dataset.
a = df[df.isnull()]
print(a)
# Out:
#       player_name player_id  season  poss  mp  raptor_offense  raptor_defense  \
# 0             NaN       NaN     NaN   NaN NaN             NaN             NaN
# 1             NaN       NaN     NaN   NaN NaN             NaN             NaN
# 2             NaN       NaN     NaN   NaN NaN             NaN             NaN
# 3             NaN       NaN     NaN   NaN NaN             NaN             NaN
# 4             NaN       NaN     NaN   NaN NaN             NaN             NaN
# ...           ...       ...     ...   ...  ..             ...             ...
# 19154         NaN       NaN     NaN   NaN NaN             NaN             NaN
# 19155         NaN       NaN     NaN   NaN NaN             NaN             NaN
# 19156         NaN       NaN     NaN   NaN NaN             NaN             NaN
# 19157         NaN       NaN     NaN   NaN NaN             NaN             NaN
# 19158         NaN       NaN     NaN   NaN NaN             NaN             NaN
#
# ...

# %%
#2 question 
#Drop rows with missing values and compare the size of the DataFrame before and after.
df.dropna()
# one row dropped because of missing values ( prior 19519 rows after droping the missing value row its 19158 rows
# Out:
#           player_name  player_id  season  poss    mp  raptor_offense  \
# 0      Alaa Abdelnaby  abdelal01    1991   640   303       -3.938450
# 1      Alaa Abdelnaby  abdelal01    1992  1998   959       -2.553849
# 2      Alaa Abdelnaby  abdelal01    1993  2754  1379       -2.373736
# 3      Alaa Abdelnaby  abdelal01    1994   320   159       -6.140056
# 4      Alaa Abdelnaby  abdelal01    1995   984   506       -3.846543
# ...               ...        ...     ...   ...   ...             ...
# 19154     Ivica Zubac  zubaciv01    2018   871   410       -2.903709
# 19155     Ivica Zubac  zubaciv01    2019  2345  1079       -2.362444
# 19156     Ivica Zubac  zubaciv01    2020  3447  1646        1.099849
# 19157     Ivica Zubac  zubaciv01    2021  3908  1910       -0.909039
# 19158     Ivica Zubac  zubaciv01    2022  3786  1852       -0.693765
#
#        raptor_defense  raptor_total  war_total  war_reg_season  war_playoffs  \
# ...

# %%
#3 
#15. Replace any `NaN` in `defensive_raptor` with 0 and check how it affects averages.
# finding the average of defense raptor
df.raptor_defense.mean()
# Out:
# -0.33664050183636013

# %%
# replacing the nan in defensive raptor
df.raptor_defense.fil
